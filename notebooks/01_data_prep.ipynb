# %%
import os
os.environ["SPARK_LOCAL_IP"] = "127.0.0.1"

from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("big-data-project")
    .master("local[*]")
    .config("spark.driver.host", "127.0.0.1")
    .config("spark.driver.bindAddress", "127.0.0.1")
    .config("spark.driver.extraJavaOptions", "-Djava.security.manager=allow")
    .config("spark.executor.extraJavaOptions", "-Djava.security.manager=allow")
    .getOrCreate()
)

print("Spark version:", spark.version)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/12 17:34:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Spark version: 4.0.1

# %%
# Load the full Grocery_and_Gourmet_Food JSONL file

input_path = "../Grocery_and_Gourmet_Food.jsonl"
df = spark.read.json(input_path)
df.printSchema()
df.show(5, truncate=False)
df.count()
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- helpful_vote: long (nullable = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachment_type: string (nullable = true)
#  |    |    |-- large_image_url: string (nullable = true)
#  |    |    |-- medium_image_url: string (nullable = true)
#  |    |    |-- small_image_url: string (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- title: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- verified_purchase: boolean (nullable = true)
#
# +----------+------------+------+-----------+------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------------+----------------------------+-----------------+
# |asin      |helpful_vote|images|parent_asin|rating|text                                                                                                                                                                                                                                                                                                                                                                                                                                                               |timestamp    |title                                 |user_id                     |verified_purchase|
# +----------+------------+------+-----------+------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------------+----------------------------+-----------------+
# |B00CM36GAQ|0           |[]    |B00CM36GAQ |5.0   |Excellent!! Yummy!  Great with other foods and great alone.                                                                                                                                                                                                                                                                                                                                                                                                        |1587854482395|Excellent!  Yummy!                    |AFKZENTNBQ7A7V7UXW5JJI6UGRYQ|true             |
# |B074J5WVYH|0           |[]    |B0759B7KLH |5.0   |Excellent!  The best!  I use it with my beef and broccoli and to throw in chicken and rice soup. It’s also great by itself. Yum!                                                                                                                                                                                                                                                                                                                                   |1587854400380|Delicious!!! Yum!                     |AFKZENTNBQ7A7V7UXW5JJI6UGRYQ|true             |
# |B079TRNVHX|1           |[]    |B079TRNVHX |5.0   |These are very tasty. They are extremely soft and literally melt on your tongue. The sea salt is delicious.  The packaging is nice too. Yummy, but too pricey for my budget on a regular basis.  There were 21 caramels in my container.  They are about twice the size of the Werther’s Chewy caramels that I usually purchase.  They taste excellent. I wish they had some with pecans and/or walnuts or pistachios in them. I ordered the sea salt version. Yum!|1587853224527|Extremely Delicious, but expensive imo|AFKZENTNBQ7A7V7UXW5JJI6UGRYQ|true             |
# |B07194LN2Z|0           |[]    |B07194LN2Z |5.0   |My favorite!                                                                                                                                                                                                                                                                                                                                                                                                                                                       |1581313319614|Delicious!                            |AFKZENTNBQ7A7V7UXW5JJI6UGRYQ|true             |
# |B005CD4196|7           |[]    |B005CD4196 |5.0   |Great for making brownies and crinkle cookies.                                                                                                                                                                                                                                                                                                                                                                                                                     |1581313294965|Great taste                           |AFKZENTNBQ7A7V7UXW5JJI6UGRYQ|true             |
# +----------+------------+------+-----------+------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------------+----------------------------+-----------------+
# only showing top 5 rows
# 14318520

# %%
# 2) Add row numbers so we can split into 3 parts

from pyspark.sql.window import Window
import pyspark.sql.functions as F
w = Window.orderBy(F.monotonically_increasing_id())
df_indexed = df.withColumn("row_num", F.row_number().over(w))
df.show ()
# Out:
# +----------+------------+--------------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# |      asin|helpful_vote|              images|parent_asin|rating|                text|    timestamp|               title|             user_id|verified_purchase|
# +----------+------------+--------------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# |B00CM36GAQ|           0|                  []| B00CM36GAQ|   5.0|Excellent!! Yummy...|1587854482395|  Excellent!  Yummy!|AFKZENTNBQ7A7V7UX...|             true|
# |B074J5WVYH|           0|                  []| B0759B7KLH|   5.0|Excellent!  The b...|1587854400380|   Delicious!!! Yum!|AFKZENTNBQ7A7V7UX...|             true|
# |B079TRNVHX|           1|                  []| B079TRNVHX|   5.0|These are very ta...|1587853224527|Extremely Delicio...|AFKZENTNBQ7A7V7UX...|             true|
# |B07194LN2Z|           0|                  []| B07194LN2Z|   5.0|        My favorite!|1581313319614|          Delicious!|AFKZENTNBQ7A7V7UX...|             true|
# |B005CD4196|           7|                  []| B005CD4196|   5.0|Great for making ...|1581313294965|         Great taste|AFKZENTNBQ7A7V7UX...|             true|
# |B07R2X568B|           0|                  []| B0BG8M4XW7|   5.0|Yummy for your tu...|1581313263026|              Yummy!|AFKZENTNBQ7A7V7UX...|             true|
# |B07LDF9V2F|           0|                  []| B07VV7T465|   5.0|This is an excell...|1552878483550|Excellent tea & s...|AFKZENTNBQ7A7V7UX...|             true|
# |B000OQXXOA|           0|                  []| B00ESE0DC4|   5.0|This is my #1 fav...|1552878387841|Like drinking a w...|AFKZENTNBQ7A7V7UX...|             true|
# |B073DCD5GC|           1|                  []| B073DDP593|   5.0|I was never a hug...|1552878262155|          Delicious!|AFKZENTNBQ7A7V7UX...|             true|
# |B009PO1JTS|           0|                  []| B009PO1JTS|   5.0|The tea is very g...|1552878208860|Yummy tea with a ...|AFKZENTNBQ7A7V7UX...|             true|
# |B00VFYPK82|           0|                  []| B01KCG2OP0|   5.0|Luckily I purchas...|1548208318951|          Yummy tea!|AFKZENTNBQ7A7V7UX...|            false|
# |B007ED2FOA|           0|                  []| B09JP7Q6W8|   5.0|I love these Clif...|1548207988441|          Delicious!|AFKZENTNBQ7A7V7UX...|             true|
# |B00FDWLITM|          14|                  []| B0C5KQVWJL|   5.0|I was at a bnb re...|1548207240942|Yummy with jasmin...|AFKZENTNBQ7A7V7UX...|             true|
# |B00ECOOV1O|          88|[{IMAGE, https://...| B08KQLCRG7|   5.0|Found a yummy tea...|1534441227514|OMG- purple tea! ...|AFKZENTNBQ7A7V7UX...|             true|
# |B00O80NU00|           0|                  []| B01NAYX4S3|   5.0|Lots of awesome tea!|1523093131195|            Love it!|AFKZENTNBQ7A7V7UX...|            false|
# |B004OT1TA8|           0|                  []| B004OT1TA8|   5.0|               yummy|1441260352000|          Five Stars|AFKZENTNBQ7A7V7UX...|             true|
# |B00EZ9GUPG|           1|                  []| B0B27QP6BG|   4.0|This hot cereal i...|1407430219000|This hot cereal i...|AGGZ357AO26RQZVRL...|             true|
# |B07F95KBXK|           2|                  []| B08CZYTZ1B|   5.0|I LOVE this stuff...|1596736699316|PERFECT ALLIUM SU...|AG2L7H23R5LLKDKLB...|             true|
# |B00RQPUV0Q|           3|                  []| B0C396H8QB|   5.0|This is absolutel...|1592532407673|EXCELLENT WATER, ...|AG2L7H23R5LLKDKLB...|             true|
# |B07934PJW2|           1|                  []| B07932BBRK|   5.0|I highly recommen...|1591312855733|My nearby grocery...|AG2L7H23R5LLKDKLB...|            false|
# +----------+------------+--------------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# only showing top 20 rows

# %%
# 3) Compute sizes for three roughly equal parts

total_rows = df_indexed.count()
third = total_rows // 3
third, total_rows
# Out:
# (4772840, 14318520)

# %%
# 4) Build three DataFrames (1/3 each)
part1 = df_indexed.filter(F.col("row_num") <= third)
part2 = df_indexed.filter(
    (F.col("row_num") > third) & (F.col("row_num") <= 2 * third)
)
part3 = df_indexed.filter(F.col("row_num") > 2 * third)

# %%
# 5) Write each part as CSV (Spark will create folders with CSV files inside)

output_cols = [
    "rating", "title", "text", "asin", "parent_asin",
    "user_id", "timestamp", "helpful_vote", "verified_purchase"
]
part1.select(output_cols).write.csv("../data/grocery_reviews_part1", header=True, mode="overwrite")
part2.select(output_cols).write.csv("../data/grocery_reviews_part2", header=True, mode="overwrite")
part3.select(output_cols).write.csv("../data/grocery_reviews_part3", header=True, mode="overwrite")
# Out:
# 25/12/12 17:34:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:34:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:34:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:35:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:35:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:36:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:36:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:36:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:37:04 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:37:04 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:38:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:38:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:38:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:38:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/12 17:38:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.

# %%
df.printSchema()
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- helpful_vote: long (nullable = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachment_type: string (nullable = true)
#  |    |    |-- large_image_url: string (nullable = true)
#  |    |    |-- medium_image_url: string (nullable = true)
#  |    |    |-- small_image_url: string (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- title: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- verified_purchase: boolean (nullable = true)

# %%
import pyspark.sql.functions as F

string_cols = ["title", "text", "asin", "user_id"]      # string
numeric_cols = ["rating", "timestamp"]                  # numeric

null_counts = df.select(
    # real nulls on numeric cols
    *[F.count(F.when(F.col(c).isNull(), c)).alias(c) for c in numeric_cols],
    # nulls or empty string on string cols
    *[F.count(F.when(F.col(c).isNull() | (F.col(c) == ""), c)).alias(c) for c in string_cols],
)

null_counts.show()
# Out:
# [Stage 18:===================================================>    (41 + 4) / 45]
# +------+---------+-----+----+----+-------+
# |rating|timestamp|title|text|asin|user_id|
# +------+---------+-----+----+----+-------+
# |     0|        0|    0| 704|   0|      0|
# +------+---------+-----+----+----+-------+

# %%
df.select("rating", "helpful_vote").describe().show()
# Out:
# [Stage 21:===================================================>    (41 + 4) / 45]
# +-------+------------------+------------------+
# |summary|            rating|      helpful_vote|
# +-------+------------------+------------------+
# |  count|          14318520|          14318520|
# |   mean| 4.122820375290184|0.9733498294516473|
# | stddev|1.4419760356357534|14.683534093775904|
# |    min|               0.0|                -1|
# |    max|               5.0|             27883|
# +-------+------------------+------------------+

# %%
df.groupBy("verified_purchase").count().show()
df.groupBy("rating").count().orderBy("rating").show()
# Out:
# +-----------------+--------+
# |verified_purchase|   count|
# +-----------------+--------+
# |             true|13176519|
# |            false| 1142001|
# +-----------------+--------+
# [Stage 27:===================================================>    (41 + 4) / 45]
# +------+-------+
# |rating|  count|
# +------+-------+
# |   0.0|      1|
# |   1.0|1855049|
# |   2.0| 695428|
# |   3.0| 898317|
# |   4.0|1256795|
# |   5.0|9612930|
# +------+-------+
